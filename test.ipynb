# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimidriss/graph_SBM_CTGAN-1/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# bin@                        lib32@                    root/
# boot/                       lib64@                    run/
# content/                    libx32@                   sbin@
# cuda-keyring_1.1-1_all.deb  media/                    srv/
# datalab/                    mnt/                      sys/
# dev/                        NGC-DL-CONTAINER-LICENSE  tmp/
# etc/                        opt/                      tools/
# home/                       proc/                     usr/
# kaggle/                     python-apt/               var/
# lib@                        python-apt.tar.xz*
